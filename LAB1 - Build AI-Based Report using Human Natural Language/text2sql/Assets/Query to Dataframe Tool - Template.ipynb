# %% [markdown]
# ## Configuration

# %% [markdown]
# Follow instruction given from github repo to see something similar like below:
#
# ```
# import os, types
# import pandas as pd
# from botocore.client import Config
# import ibm_boto3
#
# def __iter__(self): return 0
#
# # @hidden_cell
# # The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# # You might want to remove those credentials before you share the notebook.
#
# cos_client = ibm_boto3.client(service_name='s3',
#     ibm_api_key_id='<COS API KEY>',
#     ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
#     config=Config(signature_version='oauth'),
#     endpoint_url='<COS ENDPOINT>')
#
# bucket = '<COS BUCKET NAME>'
# object_key = 'data_api_ws.csv'
#
# body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# # add missing __iter__ method, so pandas accepts body as file-like object
# if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
#
# df_1 = pd.read_csv(body, sep=";")
# df_1.head(10)
# ```

# %%
# Insert data that you have uploaded in this cell
# Refer to previous markdown to see sample of generated code

# %%
ibm_api_key_id='<API KEY retrieved from previous cell>'
endpoint_url='<ENDPOINT retrieved from previous cell>'
bucket_name = '<BUCKET NAME retrieved from previous cell>'

# %%
def query_api_data(sql_query):
    import sqlite3
    import pandas as pd

    import os, types
    import pandas as pd
    from botocore.client import Config
    import ibm_boto3
    
    def __iter__(self): return 0
    
    # @hidden_cell
    # The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
    # You might want to remove those credentials before you share the notebook.
    
    cos_client = ibm_boto3.client(service_name='s3',
        ibm_api_key_id=ibm_api_key_id,
        ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
        config=Config(signature_version='oauth'),
        endpoint_url=endpoint_url)
    
    bucket = bucket_name
    object_key = 'data_api_ws.csv'
    
    body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
    # add missing __iter__ method, so pandas accepts body as file-like object
    if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
    
    df_1 = pd.read_csv(body, sep=';')
    
    # Create in-memory SQLite database
    conn = sqlite3.connect(':memory:')
    
    # Write DataFrame to SQL table
    df_1.to_sql('data_api_ws', conn, index=False, if_exists='replace')
    
    # Query it
    result = pd.read_sql_query(sql_query, conn)
    
    conn.close()

    return result.to_dict(orient='records')

# %%
sql_query = "SELECT `request id` FROM data_api_ws LIMIT 3"

# %%
query_api_data(sql_query)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 query_api_data(sql_query)
#
# Cell In[3], line 16, in query_api_data(sql_query)
#      10 def __iter__(self): return 0
#      12 # @hidden_cell
#      13 # The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
#      14 # You might want to remove those credentials before you share the notebook.
# ---> 16 cos_client = ibm_boto3.client(service_name='s3',
#      17     ibm_api_key_id=ibm_api_key_id,
#      18     ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
#      19     config=Config(signature_version='oauth'),
#      20     endpoint_url=endpoint_url)
#      22 bucket = bucket_name
#      23 object_key = 'data_api_ws.csv'
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_boto3/__init__.py:97, in client(*args, **kwargs)
#      91 def client(*args, **kwargs):
#      92     """
#      93     Create a low-level service client by name using the default session.
#      94
#      95     See :py:meth:`ibm_boto3.session.Session.client`.
#      96     """
# ---> 97     return _get_default_session().client(*args, **kwargs)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_boto3/session.py:357, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, ibm_api_key_id, ibm_service_instance_id, ibm_auth_endpoint, auth_function, token_manager, config)
#     252 def client(
#     253     self,
#     254     service_name,
#    (...)
#     268     config=None,
#     269 ):
#     270     """
#     271     Create a low-level service client by name.
#     272
#    (...)
#     355
#     356     """
# --> 357     return self._session.create_client(
#     358         service_name,
#     359         region_name=region_name,
#     360         api_version=api_version,
#     361         use_ssl=use_ssl,
#     362         verify=verify,
#     363         endpoint_url=endpoint_url,
#     364         aws_access_key_id=aws_access_key_id,
#     365         aws_secret_access_key=aws_secret_access_key,
#     366         aws_session_token=aws_session_token,
#     367         ibm_api_key_id=ibm_api_key_id,
#     368         ibm_service_instance_id=ibm_service_instance_id,
#     369         ibm_auth_endpoint=ibm_auth_endpoint,
#     370         auth_function=auth_function,
#     371         token_manager=token_manager,
#     372         config=config,
#     373     )
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_botocore/session.py:1059, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, ibm_api_key_id, ibm_service_instance_id, ibm_auth_endpoint, auth_function, token_manager, config)
#    1043 self._add_configured_endpoint_provider(
#    1044     client_name=service_name,
#    1045     config_store=config_store,
#    1046 )
#    1047 client_creator = ibm_botocore.client.ClientCreator(
#    1048     loader,
#    1049     endpoint_resolver,
#    (...)
#    1057     user_agent_creator=user_agent_creator,
#    1058 )
# -> 1059 client = client_creator.create_client(
#    1060     service_name=service_name,
#    1061     region_name=region_name,
#    1062     is_secure=use_ssl,
#    1063     endpoint_url=endpoint_url,
#    1064     verify=verify,
#    1065     credentials=credentials,
#    1066     scoped_config=self.get_scoped_config(),
#    1067     client_config=config,
#    1068     api_version=api_version,
#    1069     auth_token=auth_token,
#    1070 )
#    1071 monitor = self._get_internal_component('monitor')
#    1072 if monitor is not None:
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_botocore/client.py:160, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     147 # IBM Unsupported
#     148 # region_name, client_config = self._normalize_fips_region(
#     149 #     region_name, client_config)
#     150 endpoint_bridge = ClientEndpointBridge(
#     151     self._endpoint_resolver,
#     152     scoped_config,
#    (...)
#     158     ),
#     159 )
# --> 160 client_args = self._get_client_args(
#     161     service_model,
#     162     region_name,
#     163     is_secure,
#     164     endpoint_url,
#     165     verify,
#     166     credentials,
#     167     scoped_config,
#     168     client_config,
#     169     endpoint_bridge,
#     170     auth_token,
#     171     endpoints_ruleset_data,
#     172     partition_data,
#     173 )
#     174 service_client = cls(**client_args)
#     175 self._register_retries(service_client)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_botocore/client.py:492, in ClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     468 def _get_client_args(
#     469     self,
#     470     service_model,
#    (...)
#     481     partition_data,
#     482 ):
#     483     args_creator = ClientArgsCreator(
#     484         self._event_emitter,
#     485         self._user_agent,
#    (...)
#     490         user_agent_creator=self._user_agent_creator,
#     491     )
# --> 492     return args_creator.get_client_args(
#     493         service_model,
#     494         region_name,
#     495         is_secure,
#     496         endpoint_url,
#     497         verify,
#     498         credentials,
#     499         scoped_config,
#     500         client_config,
#     501         endpoint_bridge,
#     502         auth_token,
#     503         endpoints_ruleset_data,
#     504         partition_data,
#     505     )
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_botocore/args.py:137, in ClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     134 new_config = Config(**config_kwargs)
#     135 endpoint_creator = EndpointCreator(event_emitter)
# --> 137 endpoint = endpoint_creator.create_endpoint(
#     138     service_model,
#     139     region_name=endpoint_region_name,
#     140     endpoint_url=endpoint_config['endpoint_url'],
#     141     verify=verify,
#     142     response_parser_factory=self._response_parser_factory,
#     143     max_pool_connections=new_config.max_pool_connections,
#     144     proxies=new_config.proxies,
#     145     timeout=(new_config.connect_timeout, new_config.read_timeout),
#     146     socket_options=socket_options,
#     147     client_cert=new_config.client_cert,
#     148     proxies_config=new_config.proxies_config,
#     149 )
#     151 serializer = ibm_botocore.serialize.create_serializer(
#     152     protocol, parameter_validation
#     153 )
#     154 response_parser = ibm_botocore.parsers.create_parser(protocol)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_botocore/endpoint.py:402, in EndpointCreator.create_endpoint(self, service_model, region_name, endpoint_url, verify, response_parser_factory, timeout, max_pool_connections, http_session_cls, proxies, socket_options, client_cert, proxies_config)
#     384 def create_endpoint(
#     385     self,
#     386     service_model,
#    (...)
#     397     proxies_config=None,
#     398 ):
#     399     if not is_valid_endpoint_url(
#     400         endpoint_url
#     401     ) and not is_valid_ipv6_endpoint_url(endpoint_url):
# --> 402         raise ValueError("Invalid endpoint: %s" % endpoint_url)
#     404     if proxies is None:
#     405         proxies = self._get_proxies(endpoint_url)
#
# ValueError: Invalid endpoint: <ENDPOINT retrieved from previous cell>

# %%
print()
